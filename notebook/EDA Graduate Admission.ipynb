# %% [markdown]
# Graduate Admission for UCLA Indian perspective

# %% [markdown]
# 1) Problem Statemetn
# Understand how different grades and activites affected the admission rate: GRE Score,TOEFL Score,University Rating,SOP,LOR ,CGPA,Research

# %% [markdown]
# 2) Data collection
# from kaggle
# 7 column 500 rows

# %% [markdown]
# 2.1
# Import lib

# %%
import numpy as numpy
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Import the csv

# %%
df = pd.read_csv('data/Admission_Predict_Ver1.1.csv')

# %% [markdown]
# Check the data base if imported

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %% [markdown]
# Shape

# %%
df.shape
# Out:
# (500, 9)

# %% [markdown]
# 3 Check data
# 1 check missing values
# 2 check dup
# 3 check type
# 4 check unique values in each column
# 5 statistic of data set
# 6 check varioys cat present in different categorial column

# %%
df.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# no missing value

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no dup

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.nunique()
# Out:
# Serial No.           500
# GRE Score             49
# TOEFL Score           29
# University Rating      5
# SOP                    9
# LOR                    9
# CGPA                 184
# Research               2
# Chance of Admit       61
# dtype: int64

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']  
#should no categorial features in this dataset because all int or float
print(f'Numerical features: {numerical_features}')
print(f'Categorical features: {categorical_features}')
# Out:
# Numerical features: ['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Research', 'Chance of Admit ']
# Categorical features: []

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %% [markdown]
# 4 histogram and KDE

# %%
fig, axs = plt.subplots(2, 2, figsize=(20, 10))
plt.subplot(121)
sns.histplot(df['GRE Score'], kde=True)
plt.subplot(122)
sns.histplot(df['TOEFL Score'], kde=True)
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.subplot(121)
sns.histplot(df['University Rating'], kde=True)
plt.subplot(122)        
sns.histplot(df['SOP'], kde=True)
plt.show()
